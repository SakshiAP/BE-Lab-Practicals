# %%
# Assignment No. 5:- Implement the Continuous Bag of Words (CBOW) Model

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Embedding, Dense, Lambda
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences


# Sample text data (replace with your own text data)
corpus = [
    'this is a sample sentence',
    'continuous bag of words model',
    'implementation of cbow',
    'natural language processing',
    'deep learning for nlp tasks',
]

# Stage a: Data Preparation
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
vocab_size = len(tokenizer.word_index) + 1

# Generate word sequences and context-target pairs for CBOW
context_window = 2

def generate_training_data(corpus, tokenizer, window_size):
    sequences = tokenizer.texts_to_sequences(corpus)
    X = []
    y = []
    for sequence in sequences:
        for i in range(window_size, len(sequence) - window_size):
            context = sequence[i - window_size:i] + sequence[i + 1:i + window_size + 1]
            target = sequence[i]
            X.append(context)
            y.append(target)
    return np.array(X), np.array(y)

X_train, y_train = generate_training_data(corpus, tokenizer, context_window)

# Stage b: Generate training data (completed above)

# Stage c: Train CBOW model
embedding_dim = 50

model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=context_window * 2),
    Lambda(lambda x: tf.reduce_mean(x, axis=1)),
    Dense(units=vocab_size, activation='softmax')
])

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')
model.fit(X_train, y_train, epochs=100, verbose=2)

# Stage d: Output
word_embeddings = model.layers[0].get_weights()[0]

# Function to find the closest words to a given word
def find_closest_words(word_embeddings, target_word, tokenizer, top_n=5):
    target_word_index = tokenizer.word_index.get(target_word)
    if target_word_index is None:
        return []

    target_embedding = word_embeddings[target_word_index]
    distances = np.linalg.norm(word_embeddings - target_embedding, axis=1)
    closest_indices = np.argsort(distances)[1:top_n + 1]
    closest_words = [word for word, index in tokenizer.word_index.items() if index in closest_indices]
    return closest_words

# Test the CBOW model by finding closest words
target_word = 'cbow'
closest_words = find_closest_words(word_embeddings, target_word, tokenizer)
print(f"Closest words to '{target_word}': {closest_words}")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Epoch 1/100
# 1/1 - 1s - loss: 3.0381 - 558ms/epoch - 558ms/step
# Epoch 2/100
# 1/1 - 0s - loss: 3.0288 - 4ms/epoch - 4ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 3.0195 - 5ms/epoch - 5ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 3.0102 - 5ms/epoch - 5ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 3.0009 - 4ms/epoch - 4ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 2.9916 - 3ms/epoch - 3ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 2.9823 - 5ms/epoch - 5ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 2.9729 - 4ms/epoch - 4ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 2.9635 - 4ms/epoch - 4ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 2.9540 - 4ms/epoch - 4ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 2.9445 - 5ms/epoch - 5ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 2.9350 - 3ms/epoch - 3ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 2.9253 - 5ms/epoch - 5ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 2.9156 - 5ms/epoch - 5ms/step
# Epoch 15/100
# 1/1 - 0s - loss: 2.9058 - 3ms/epoch - 3ms/step
# Epoch 16/100
# 1/1 - 0s - loss: 2.8958 - 4ms/epoch - 4ms/step
# Epoch 17/100
# 1/1 - 0s - loss: 2.8858 - 4ms/epoch - 4ms/step
# Epoch 18/100
# 1/1 - 0s - loss: 2.8757 - 4ms/epoch - 4ms/step
# Epoch 19/100
# 1/1 - 0s - loss: 2.8654 - 4ms/epoch - 4ms/step
# Epoch 20/100
# 1/1 - 0s - loss: 2.8550 - 4ms/epoch - 4ms/step
# Epoch 21/100
# 1/1 - 0s - loss: 2.8445 - 4ms/epoch - 4ms/step
# Epoch 22/100
# 1/1 - 0s - loss: 2.8338 - 5ms/epoch - 5ms/step
# Epoch 23/100
# 1/1 - 0s - loss: 2.8230 - 4ms/epoch - 4ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 2.8121 - 4ms/epoch - 4ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 2.8010 - 4ms/epoch - 4ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 2.7897 - 4ms/epoch - 4ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 2.7783 - 4ms/epoch - 4ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 2.7666 - 4ms/epoch - 4ms/step
# Epoch 29/100
# 1/1 - 0s - loss: 2.7549 - 3ms/epoch - 3ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 2.7429 - 11ms/epoch - 11ms/step
# Epoch 31/100
# 1/1 - 0s - loss: 2.7308 - 5ms/epoch - 5ms/step
# Epoch 32/100
# 1/1 - 0s - loss: 2.7184 - 4ms/epoch - 4ms/step
# Epoch 33/100
# 1/1 - 0s - loss: 2.7059 - 4ms/epoch - 4ms/step
# Epoch 34/100
# 1/1 - 0s - loss: 2.6932 - 5ms/epoch - 5ms/step
# Epoch 35/100
# 1/1 - 0s - loss: 2.6803 - 5ms/epoch - 5ms/step
# Epoch 36/100
# 1/1 - 0s - loss: 2.6671 - 3ms/epoch - 3ms/step
# Epoch 37/100
# 1/1 - 0s - loss: 2.6538 - 4ms/epoch - 4ms/step
# Epoch 38/100
# 1/1 - 0s - loss: 2.6403 - 4ms/epoch - 4ms/step
# Epoch 39/100
# 1/1 - 0s - loss: 2.6265 - 3ms/epoch - 3ms/step
# Epoch 40/100
# 1/1 - 0s - loss: 2.6126 - 4ms/epoch - 4ms/step
# Epoch 41/100
# 1/1 - 0s - loss: 2.5984 - 5ms/epoch - 5ms/step
# Epoch 42/100
# 1/1 - 0s - loss: 2.5840 - 3ms/epoch - 3ms/step
# Epoch 43/100
# 1/1 - 0s - loss: 2.5694 - 3ms/epoch - 3ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 2.5546 - 4ms/epoch - 4ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 2.5395 - 3ms/epoch - 3ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 2.5243 - 5ms/epoch - 5ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 2.5087 - 4ms/epoch - 4ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 2.4930 - 3ms/epoch - 3ms/step
# Epoch 49/100
# 1/1 - 0s - loss: 2.4771 - 4ms/epoch - 4ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 2.4609 - 5ms/epoch - 5ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 2.4444 - 3ms/epoch - 3ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 2.4278 - 5ms/epoch - 5ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 2.4109 - 4ms/epoch - 4ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 2.3938 - 4ms/epoch - 4ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 2.3765 - 3ms/epoch - 3ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 2.3589 - 4ms/epoch - 4ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 2.3411 - 4ms/epoch - 4ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 2.3231 - 4ms/epoch - 4ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 2.3049 - 4ms/epoch - 4ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 2.2864 - 3ms/epoch - 3ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 2.2677 - 4ms/epoch - 4ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 2.2488 - 3ms/epoch - 3ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 2.2297 - 3ms/epoch - 3ms/step
# Epoch 64/100
# 1/1 - 0s - loss: 2.2104 - 3ms/epoch - 3ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 2.1909 - 4ms/epoch - 4ms/step
# Epoch 66/100
# 1/1 - 0s - loss: 2.1711 - 3ms/epoch - 3ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 2.1512 - 3ms/epoch - 3ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 2.1310 - 3ms/epoch - 3ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 2.1106 - 3ms/epoch - 3ms/step
# Epoch 70/100
# 1/1 - 0s - loss: 2.0901 - 3ms/epoch - 3ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 2.0693 - 3ms/epoch - 3ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 2.0484 - 4ms/epoch - 4ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 2.0273 - 3ms/epoch - 3ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 2.0060 - 3ms/epoch - 3ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 1.9846 - 4ms/epoch - 4ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 1.9629 - 3ms/epoch - 3ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 1.9411 - 3ms/epoch - 3ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 1.9192 - 3ms/epoch - 3ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 1.8971 - 4ms/epoch - 4ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 1.8749 - 3ms/epoch - 3ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 1.8525 - 3ms/epoch - 3ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 1.8300 - 4ms/epoch - 4ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 1.8074 - 3ms/epoch - 3ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 1.7846 - 3ms/epoch - 3ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 1.7618 - 3ms/epoch - 3ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 1.7389 - 4ms/epoch - 4ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 1.7158 - 3ms/epoch - 3ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 1.6927 - 3ms/epoch - 3ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 1.6695 - 3ms/epoch - 3ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 1.6463 - 3ms/epoch - 3ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 1.6229 - 3ms/epoch - 3ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 1.5996 - 4ms/epoch - 4ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 1.5762 - 3ms/epoch - 3ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 1.5527 - 3ms/epoch - 3ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 1.5293 - 3ms/epoch - 3ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 1.5059 - 5ms/epoch - 5ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 1.4824 - 3ms/epoch - 3ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 1.4590 - 3ms/epoch - 3ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 1.4356 - 4ms/epoch - 4ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 1.4122 - 3ms/epoch - 3ms/step
# Closest words to 'cbow': ['of', 'a', 'language', 'processing', 'for']
